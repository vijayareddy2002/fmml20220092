# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayareddy2002/fmml20220092/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 04:30:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   101MB/s    in 0.7s
#
# 2023-05-27 04:30:31 (101 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12477  1802.04826v3  Deep latent variable models combine the approx...  stat
# 5670   1604.05819v1  Predictive models are finding an increasing nu...  stat
# 26307  1609.07986v3  A new resolution enhancement method is present...    cs
# 10683   1206.6487v1  We present a new anytime algorithm that achiev...    cs
# 23724   1104.4298v2  Gabor filters play an important role in many a...    cs
# ...             ...                                                ...   ...
# 12585  1803.02398v1  Protein-ligand scoring is an important step in...  stat
# 22505  1610.04811v2  Density matrices are positively semi-definite ...  stat
# 206    1612.04052v1  Deep convolutional neural networks (CNNs) have...  stat
# 31620  1803.07739v1  It is known that humans display "shape bias" w...    cs
# 20863  1704.03048v1  The media industry is increasingly personalizi...    cs
#
#                                                    title  year  \
# 12477  Leveraging the Exact Likelihood of Deep Latent...  2018
# 5670   Trading-Off Cost of Deployment Versus Accuracy...  2016
# 26307  Super-resolving multiresolution images with ba...  2016
# 10683  An Adaptive Algorithm for Finite Stochastic Pa...  2012
# 23724  Curved Gabor Filters for Fingerprint Image Enh...  2011
# ...                                                  ...   ...
# 12585  Visualizing Convolutional Neural Network Prote...  2018
# 22505  Estimation of low rank density matrices by Pau...  2016
# 206    Theory and Tools for the Conversion of Analog ...  2016
# 31620  Assessing Shape Bias Property of Convolutional...  2018
# 20863  Matching Media Contents with User Profiles by ...  2017
#
#                                                 keywords
# 12477  [approximation, abilities, statistical, founda...
# 5670   [predictive, increasing, applications, industr...
# 26307  [resolution, enhancement, presented, multispec...
# 10683  [algorithm, stochastic, monitoring, particular...
# 23724  [important, application, enhancement, extracti...
# ...                                                  ...
# 12585  [important, structure, selecting, predicting, ...
# 22505  [positively, hermitian, represented, dimension...
# 206    [convolutional, potential, applications, perfo...
# 31620  [classifying, categorize, convolutional, struc...
# 20863  [increasingly, personalizing, relationships, e...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12477    [approximation, abilities, statistical, founda...
# 5670     [predictive, increasing, applications, industr...
# 26307    [resolution, enhancement, presented, multispec...
# 10683    [algorithm, stochastic, monitoring, particular...
# 23724    [important, application, enhancement, extracti...
#                                ...
# 2296     [optimization, objective, functions, continuou...
# 22479    [automated, variational, inference, likelihood...
# 6837     [classical, perturbation, eigenvalues, eigenve...
# 21516    [procedure, effective, estimation, information...
# 6486     [constraints, operating, inference, translatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8857 words.
# Out of those 4622 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2230f686-5f33-4518-a291-da5437e1fe55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2230f686-5f33-4518-a291-da5437e1fe55")) {                    Plotly.newPlot(                        "2230f686-5f33-4518-a291-da5437e1fe55",                        [{"x":["abilities","leveraging","algorithm","statistical","particular","techniques","distribution","outperforms","extremely","consistently","continuous","illustrated","following","foundations","estimates","conditional","existence","consequently","unbounded","inference","approximation","connections","variational","generative","posedness","furthermore","imputation","significantly","unconstrained","nonparametric","likelihood","practical","approaches","challenge","application","structures","structure","sensitive","healthcare","properties","regularizers","designing","dependencies","intensive","effectiveness","industries","motivated","regularizer","challenging","resulting","significant","represent","predictive","framework","surprising","excellent","deploying","prediction","deployment","structured","applications","connection","underlying","increasing","preserving","resolution","multiresolution","presented","information","reference","resolving","separated","implementation","independent","enhancement","multispectral","propagating","satellites","reflectance","dependent","logarithmic","implication","importantly","assumptions","individual","additionally","monitoring","stochastic","additional","reasonable","extraction","comparison","experimental","constructed","enhancing","parameters","important","estimation","estimating","smoothing","orientation","fingerprint","databases","improvements","direction","frequency","respective","artifacts","introduce","generalized","functions","multivalued","describes","correspondence","operations","relations","variables","admissible","disjunction","essential","satisfaction","conjunction","membership","solutions","invariants","consistency","generalizations","invariant","necessary","polymorphisms","considers","polymorphism","polynomial","constraint","guarantee","tractable","relationships","according","observations","examination","introduced","dependence","different","description","naturally","relationship","definition","functional","evaluating","conventional","performed","localization","activations","fundamentally","convolutional","detection","demonstrate","combining","supervised","discriminative","segmentation","permitted","distributions","characteristics","languages","semantically","restricting","predefined","perplexity","interpretable","experiments","usefulness","parallelizable","communication","approximations","evolution","capturing","effective","discovering","empirical","assignments","metropolis","algorithms","documents","posterior","knowledge","baselines","environment","magnitude","distributed","embarrassingly","parameter","efficient","smoothness","computationally","arbitrary","providing","selection","algorithmic","departing"],"y":[18,39,821,182,291,386,208,262,55,40,94,19,79,10,62,94,33,36,9,198,118,49,61,110,2,171,5,282,18,18,57,132,415,151,234,128,315,63,6,231,6,49,48,28,198,1,59,26,281,160,234,114,55,560,11,28,7,201,20,97,448,44,132,89,62,119,4,182,698,66,12,10,130,131,32,12,7,6,9,91,19,6,27,57,126,53,42,127,114,52,143,129,371,61,17,245,399,208,62,23,33,8,53,103,64,55,18,22,344,79,224,2,94,21,68,87,126,4,4,79,16,15,17,144,6,70,9,75,67,1,31,1,54,93,31,37,78,113,69,10,134,23,760,69,56,74,57,50,65,106,139,62,21,7,360,347,588,103,196,102,207,3,110,98,110,30,8,13,13,37,647,24,3,53,33,65,37,260,28,153,7,5,602,78,44,348,68,113,53,109,1,104,404,13,96,77,67,178,47,1],"type":"bar"},{"x":["abilities","leveraging","algorithm","statistical","particular","techniques","distributi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4622,), (4622, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Content</span> <span style=''>GAN</span> <span style=''>for</span> <span style=''>Few</span> <span style=''>Shot</span> <span style=''>Font</span> <span style=''>Style</span> <span style=''>Transfer</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style=''>taking</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.37556561085972856);'>observations</span> <span style=''>of</span> <span style=''>highly</span> <span style=''>stylized</span> <span style=''>text</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37556561085972856);'>observations</span> <span style=''>to</span> <span style=''>generate</span> <span style='background-color:rgba(255, 0, 0, 0.40740740740740744);'>unobserved</span> <span style=''>glyphs</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ornamented</span> <span style=''>typeface</span> <span style=''>To</span> <span style=''>generate</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>content</span> <span style=''>images</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>style</span> <span style=''>from</span> <span style=''>very</span> <span style=''>few</span> <span style=''>examples</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>stacked</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>GAN</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>considering</span> <span style=''>content</span> <span style=''>along</span> <span style=''>channels</span> <span style=''>and</span> <span style=''>style</span> <span style=''>along</span> <span style=''>network</span> <span style=''>layers</span> <span style=''>Our</span> <span style=''>proposed</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>transfers</span> <span style=''>the</span> <span style=''>style</span> <span style=''>of</span> <span style=''>given</span> <span style=''>glyphs</span> <span style=''>to</span> <span style=''>the</span> <span style=''>contents</span> <span style=''>of</span> <span style=''>unseen</span> <span style=''>ones</span> <span style='background-color:rgba(0, 255, 0, 0.4509803921568628);'>capturing</span> <span style=''>highly</span> <span style=''>stylized</span> <span style=''>fonts</span> <span style=''>found</span> <span style=''>in</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>such</span> <span style=''>as</span> <span style=''>those</span> <span style=''>on</span> <span style=''>movie</span> <span style=''>posters</span> <span style=''>or</span> <span style=''>infographics</span> <span style=''>We</span> <span style=''>seek</span> <span style=''>to</span> <span style=''>transfer</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>typographic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>stylization</span> <span style=''>(ex</span> <span style=''>serifs</span> <span style=''>and</span> <span style=''>ears)</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style=''>textual</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Implicit</span> <span style=''>Bias</span> <span style=''>of</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separable</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unregularized</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problem</span> <span style=''>for</span> <span style=''>linearly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>max</span> <span style=''>margin</span> <span style=''>(hard</span> <span style=''>margin</span> <span style=''>SVM)</span> <span style=''>solution</span> <span style=''>The</span> <span style=''>result</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>also</span> <span style=''>to</span> <span style=''>other</span> <span style=''>monotone</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreasing</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>with</span> <span style=''>an</span> <span style=''>infimum</span> <span style=''>at</span> <span style=''>infinity</span> <span style=''>to</span> <span style=''>multi</span> <span style=''>class</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>to</span> <span style=''>training</span> <span style=''>a</span> <span style=''>weight</span> <span style=''>layer</span> <span style=''>in</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>network</span> <span style=''>in</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>setting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>show</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>is</span> <span style=''>very</span> <span style=''>slow</span> <span style=''>and</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>logarithmic</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>itself</span> <span style=''>This</span> <span style=''>can</span> <span style=''>help</span> <span style=''>explain</span> <span style=''>the</span> <span style=''>benefit</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuing</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>the</span> <span style=''>logistic</span> <span style=''>or</span> <span style=''>cross</span> <span style=''>entropy</span> <span style=''>loss</span> <span style=''>even</span> <span style=''>after</span> <span style=''>the</span> <span style=''>training</span> <span style=''>error</span> <span style=''>is</span> <span style=''>zero</span> <span style=''>and</span> <span style=''>the</span> <span style=''>training</span> <span style=''>loss</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style=''>small</span> <span style=''>and</span> <span style=''>as</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.5072463768115942);'>Dirichlet</span> <span style=''>Scaling</span> <span style=''>Process</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>textithierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.5072463768115942);'>Dirichlet</span> <span style=''>scaling</span> <span style=''>process</span> <span style=''>(HDSP)</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.7482517482517483);'>nonparametric</span> <span style=''>mixed</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>membership</span> <span style=''>model</span> <span style=''>The</span> <span style=''>HDSP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.5072463768115942);'>Dirichlet</span> <span style=''>process</span> <span style=''>(HDP)</span> <span style=''>to</span> <span style=''>model</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>between</span> <span style=''>metadata</span> <span style=''>in</span> <span style=''>the</span> <span style=''>corpus</span> <span style=''>and</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>the</span> <span style=''>HDSP</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>gamma</span> <span style='background-color:rgba(0, 255, 0, 0.35104364326375714);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5072463768115942);'>Dirichlet</span> <span style=''>process</span> <span style=''>and</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>allows</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>incorporating</span> <span style=''>a</span> <span style=''>scaling</span> <span style=''>function</span> <span style=''>that</span> <span style=''>controls</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>membership</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>two</span> <span style=''>scaling</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.330998248686515);'>different</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.4093264248704663);'>assumptions</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>HDSP</span> <span style=''>We</span> <span style=''>also</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.5963302752293578);'>posterior</span> <span style='backgroun ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Disease</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Trajectory</span> <span style=''>Maps</span> <br/><br/><span style=''>Medical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>are</span> <span style=''>coming</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appreciate</span> <span style=''>that</span> <span style=''>many</span> <span style=''>diseases</span> <span style=''>are</span> <span style=''>in</span> <span style=''>fact</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style=''>syndromes</span> <span style=''>composed</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subpopulations</span> <span style=''>that</span> <span style=''>express</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>a</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complication</span> <span style=''>Time</span> <span style=''>series</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>electronic</span> <span style=''>health</span> <span style=''>records</span> <span style=''>(EHR)</span> <span style=''>offer</span> <span style=''>an</span> <span style=''>exciting</span> <span style=''>new</span> <span style=''>way</span> <span style=''>to</span> <span style=''>study</span> <span style=''>subtle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>in</span> <span style=''>the</span> <span style=''>way</span> <span style=''>these</span> <span style=''>diseases</span> <span style=''>progress</span> <span style=''>over</span> <span style=''>time</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>answering</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>asked</span> <span style=''>using</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style=''>First</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>whether</span> <span style=''>there</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individuals</span> <span style=''>with</span> <span style=''>similar</span> <span style=''>disease</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>and</span> <span style=''>whether</span> <span style=''>there</span> <span style=''>are</span> <span style=''>a</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style=''>degrees</span> <span style=''>of</span> <span style=''>freedom</span> <span style=''>that</span> <span style=''>account</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>across</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08735795454545454)
# 	knowledge (0.12357954545454546)
# 	information (0.24786931818181818)
# 	processing (0.11044034090909091)
# 	experimental (0.1317471590909091)
# 	segmentation (0.07350852272727272)
# 	detection (0.12322443181818182)
# 	different (0.26988636363636365)
# 	recognition (0.12535511363636365)
# 	convolutional (0.1278409090909091)
#
# Some Statistics words are:
# 	statistical (0.15171370967741934)
# 	algorithm (0.3815524193548387)
# 	theoretical (0.15272177419354838)
# 	estimation (0.1688508064516129)
# 	stochastic (0.14465725806451613)
# 	variables (0.14717741935483872)
# 	distribution (0.17993951612903225)
# 	dimensional (0.19858870967741934)
# 	regression (0.18245967741935484)
# 	inference (0.2056451612903226)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a359e573-7c74-4f35-826f-724c3ac31cbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a359e573-7c74-4f35-826f-724c3ac31cbe")) {                    Plotly.newPlot(                        "a359e573-7c74-4f35-826f-724c3ac31cbe",                        [{"x":["abilities","leveraging","algorithm","statistical","particular","techniques","distribution","outperforms","extremely","consistently","continuous","illustrated","following","foundations","estimates","conditional","existence","consequently","unbounded","inference","approximation","connections","variational","generative","posedness","furthermore","imputation","significantly","unconstrained","nonparametric","likelihood","practical","approaches","challenge","application","structures","structure","sensitive","healthcare","properties","regularizers","designing","dependencies","intensive","effectiveness","industries","motivated","regularizer","challenging","resulting","significant","represent","predictive","framework","surprising","excellent","deploying","prediction","deployment","structured","applications","connection","underlying","increasing","preserving","resolution","multiresolution","presented","information","reference","resolving","separated","implementation","independent","enhancement","multispectral","propagating","satellites","reflectance","dependent","logarithmic","implication","importantly","assumptions","individual","additionally","monitoring","stochastic","additional","reasonable","extraction","comparison","experimental","constructed","enhancing","parameters","important","estimation","estimating","smoothing","orientation","fingerprint","databases","improvements","direction","frequency","respective","artifacts","introduce","generalized","functions","multivalued","describes","correspondence","operations","relations","variables","admissible","disjunction","essential","satisfaction","conjunction","membership","solutions","invariants","consistency","generalizations","invariant","necessary","polymorphisms","considers","polymorphism","polynomial","constraint","guarantee","tractable","relationships","according","observations","examination","introduced","dependence","different","description","naturally","relationship","definition","functional","evaluating","conventional","performed","localization","activations","fundamentally","convolutional","detection","demonstrate","combining","supervised","discriminative","segmentation","permitted","distributions","characteristics","languages","semantically","restricting","predefined","perplexity","interpretable","experiments","usefulness","parallelizable","communication","approximations","evolution","capturing","effective","discovering","empirical","assignments","metropolis","algorithms","documents","posterior","knowledge","baselines","environment","magnitude","distributed","embarrassingly","parameter","efficient","smoothness","computationally","arbitrary","providing","selection","algorithmic","departing","generalize","structural","inequalities","coordinates","dimensional","identifiability","sufficient","incomplete","deterministic","projections","establishes","conditions","canonical","resultant","successive","dimensions","biological","superiority","correlation","asymptotic","performance","screening","establish","expressions","implements","literature","subsequently","regression","popularly","multivariate","computational","predictor","remaining","dimension","coefficients","experimenter","complexity","subnetworks","reconstruction","attribute","connecting","generally","including","meaningful","graphical","complementary","customers","interactions","penalized","iterative","constrained","accurately","blindness","optimization","dependency","semiblind","adv ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	uhlenbeck
# 	dendrograms
# 	ultrametric
# 	distributionally
# 	convexification
# 	misspecified
# 	integrative
# 	reconstructive
# 	unintentionally
# 	nonstandard
# 	detectability
# 	metabolite
# 	metabolites
# 	renewable
# 	penetration
# 	couplings
# 	analyzers
# 	impulsive
# 	correntropy
# 	fibrillation
# Some words which never appear in Statistics papers:
# 	multivalued
# 	admissible
# 	disjunction
# 	satisfaction
# 	subnetworks
# 	blindness
# 	marketplace
# 	abduction
# 	commonsense
# 	electromagnetic
# 	propositional
# 	superpixels
# 	magnification
# 	underscores
# 	discernible
# 	proactive
# 	monocular
# 	trustworthy
# 	concatenation
# 	passwords

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.050454517723141e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7466666666666667
